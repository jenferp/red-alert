# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import os
#list of images in directory
imagepaths = list(paths.list_images('./train_images'))#need the correct pathname this is just a placeholder
data = []
labels = []

for imagepath in imagepaths:
    label = imagepath.split(os.path.sep)[-2] #extract class label from filename
    #loads each image in imagepaths and preprocesses the image
    image = load_img(imagepath, target_size=(224,224))
    image = img_to_array(image)
    image = preprocess_input(image)
    image_1d =[]
    for i in image:
        for j in i:
            for k in j:
                image_1d.append(k)
            
    #update the data and labels lists
    data.append(image_1d)
    labels.append(label)
#convert data and labels into numpy arrays
data = np.array(data)
labels = np.array(labels)

# perform one-hot encoding on the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)

# partition the data into training and testing splits using 80% of
# the data for training and the remaining 20% for testing
(trainX, testX, trainY, testY) = train_test_split(data, labels,test_size=0.20, stratify=labels, random_state=42)

# construct the training image generator for data augmentation
aug = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest")

# initialize the initial learning rate, number of epochs to train for,
# and batch size
INIT_LR = 1e-4
EPOCHS = 30
BS = 32

# load the MobileNetV2 network, leaving the head FC layer sets
baseModel = MobileNetV2(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))

# construct the head of the model that will be placed on top of the
# the base model
headModel = baseModel.output
headModel = AveragePooling2D(pool_size=(7, 7))(headModel)
headModel = Flatten(name="flatten")(headModel)
headModel = Dense(128, activation="relu")(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(2, activation="softmax")(headModel)

# place the head FC model on top of the base model
model = Model(inputs=baseModel.input, outputs=headModel)

# loop over all layers in the base model and freeze them so they wil 
# dont get updated during the first training process
for layer in baseModel.layers:
    layer.trainable = False

# compile our model
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)
model.compile(loss="binary_crossentropy", optimizer=opt,
    metrics=["accuracy"])

# train the head of the network
H = model.fit(
    aug.flow(trainX, trainY, batch_size=BS),
    steps_per_epoch=len(trainX) // BS,
    validation_data=(testX, testY),
    validation_steps=len(testX) // BS,
    epochs=EPOCHS)

# make predictions on the testing set
predIdxs = model.predict(testX, batch_size=BS)

# for each image in the testing set we need to find the index of the
# label with corresponding largest predicted probability
predIdxs = np.argmax(predIdxs, axis=1)
# show a nicely formatted classification report
print(classification_report(testY.argmax(axis=1), predIdxs, target_names=lb.classes_))

# show a nicely formatted classification report
print(confusion_matrix(testY.argmax(axis=1), predIdxs))

# show a nicely formatted classification report
print(accuracy_score(testY.argmax(axis=1), predIdxs))

# plot the training loss and accuracy
N = EPOCHS
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), H.history["acc"], label="train_acc")
plt.plot(np.arange(0, N), H.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig('model_plot.png')

# %%
print(len(image_1d))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b75efba6dee7> in <module>
# ----> 1 print(len(image_1d))
#
# NameError: name 'image_1d' is not defined

# %%
# !conda update mkl
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::anaconda==2020.11=py38_0
# done
#
# ## Package Plan ##
#
#   environment location: /Users/jenniferpark/opt/anaconda3
#
#   added / updated specs:
#     - mkl
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2020.07  |           py38_0           6 KB
#     alabaster-0.7.12           |     pyhd3eb1b0_0          16 KB
#     anaconda-custom            |           py38_1          35 KB
#     anaconda-project-0.9.1     |     pyhd3eb1b0_1         215 KB
#     appdirs-1.4.4              |             py_0          13 KB
#     appnope-0.1.2              |py38hecd8cb5_1001          10 KB
#     appscript-1.1.2            |   py38h9ed2024_0         129 KB
#     argon2-cffi-20.1.0         |   py38h9ed2024_1          44 KB
#     astroid-2.5                |   py38hecd8cb5_1         284 KB
#     astropy-4.2                |   py38h9ed2024_0         6.1 MB
#     autopep8-1.5.5             |     pyhd3eb1b0_0          42 KB
#     babel-2.9.0                |     pyhd3eb1b0_0         5.5 MB
#     backcall-0.2.0             |     pyhd3eb1b0_0          13 KB
#     backports-1.0              |     pyhd3eb1b0_2         210 KB
#     backports.functools_lru_cache-1.6.1|     pyhd3eb1b0_0          12 KB
#     backports.shutil_get_terminal_size-1.0.0|     pyhd3eb1b0_3          10 KB
#     backports.tempfile-1.0     |     pyhd3eb1b0_1          11 KB
#     beautifulsoup4-4.9.3       |     pyha847dfd_0          86 KB
#     bitarray-1.6.3             |   py38h9ed2024_1          92 KB
#     black-19.10b0              |             py_0          86 KB
#     bleach-3.3.0               |     pyhd3eb1b0_0         113 KB
#     blosc-1.21.0               |       h2842e9f_0          49 KB
#     brotlipy-0.7.0             |py38h9ed2024_1003         331 KB
#     ca-certificates-2021.1.19  |       hecd8cb5_0         121 KB
#     certifi-2020.12.5          |   py38hecd8cb5_0         141 KB
#     cffi-1.14.5                |   py38h2125817_0         218 KB
#     chardet-3.0.4              |py38hecd8cb5_1003         175 KB
#     click-7.1.2                |     pyhd3eb1b0_0          64 KB
#     colorama-0.4.4             |     pyhd3eb1b0_0          21 KB
#     cryptography-3.3.1         |   py38hbcfaee0_1         564 KB
#     cython-0.29.22             |   py38h23ab428_0         1.9 MB
#     dask-2021.2.0              |     pyhd3eb1b0_0           5 KB
#     dask-core-2021.2.0         |     pyhd3eb1b0_0         643 KB
#     decorator-4.4.2            |     pyhd3eb1b0_0          12 KB
#     defusedxml-0.6.0           |     pyhd3eb1b0_0          23 KB
#     distributed-2021.2.0       |   py38hecd8cb5_0         1.0 MB
#     filelock-3.0.12            |     pyhd3eb1b0_1          10 KB
#     flask-1.1.2                |     pyhd3eb1b0_0          70 KB
#     gevent-21.1.1              |   py38h9ed2024_1         1.5 MB
#     glib-2.67.4                |       hdf23fa2_1         2.7 MB
#     glob2-0.7                  |     pyhd3eb1b0_0          12 KB
#     gmp-6.2.1                  |       h23ab428_2         512 KB
#     greenlet-1.0.0             |   py38h23ab428_2          78 KB
#     idna-2.10                  |     pyhd3eb1b0_0          52 KB
#     imagesize-1.2.0            |     pyhd3eb1b0_0           8 KB
#     iniconfig-1.1.1            |     pyhd3eb1b0_0           8 KB
#     ipython-7.20.0             |   py38h01d92e1_1         995 KB
#     ipython_genutils-0.2.0     |     pyhd3eb1b0_1          27 KB
#     ipywidgets-7.6.3           |     pyhd3eb1b0_1         105 KB
#     isort-5.7.0                |     pyhd3eb1b0_0          82 KB
#     itsdangerous-1.1.0         |     pyhd3eb1b0_0          17 KB
#     jedi-0.17.2                |   py38hecd8cb5_1         923 KB
#     jinja2-2.11.3              |     pyhd3eb1b0_0         101 KB
#     joblib-1.0.1               |     pyhd3eb1b0_0         208 KB
#     jupyter_core-4.7.1         |   py38hecd8cb5_0          68 KB
#     jupyterlab_widgets-1.0.0   |     pyhd3eb1b0_1         109 KB
#     keyring-22.0.1             |   py38hecd8cb5_0          54 KB
#     kiwisolver-1.3.1           |   py38h23ab428_0          52 KB
#     lazy-object-proxy-1.5.2    |   py38h9ed2024_0          26 KB
#     libllvm9-9.0.1             |       h21ff451_1        15.4 MB
#     locket-0.2.1               |   py38hecd8cb5_1          10 KB
#     lxml-4.6.2                 |   py38h26b266a_0         1.1 MB
#     lz4-c-1.9.3                |       h23ab428_0         140 KB
#     matplotlib-3.3.4           |   py38hecd8cb5_0          26 KB
#     matplotlib-base-3.3.4      |   py38h8b3ea08_0         5.1 MB
#     mkl-service-2.3.0          |   py38h9ed2024_0          41 KB
#     mkl_fft-1.2.1              |   py38ha059aab_0         144 KB
#     mock-4.0.3                 |     pyhd3eb1b0_0          29 KB
#     more-itertools-8.7.0       |     pyhd3eb1b0_0          42 KB
#     msgpack-python-1.0.2       |   py38hf7b0b51_1          75 KB
#     mypy_extensions-0.4.3      |           py38_0           9 KB
#     nbformat-5.1.2             |     pyhd3eb1b0_1          68 KB
#     nose-1.3.7                 |  pyhd3eb1b0_1006         128 KB
#     notebook-6.2.0             |   py38hecd8cb5_0         4.1 MB
#     numexpr-2.7.2              |   py38h16bde0e_0         120 KB
#     openpyxl-3.0.6             |     pyhd3eb1b0_0         159 KB
#     openssl-1.1.1j             |       h9ed2024_0         2.2 MB
#     packaging-20.9             |     pyhd3eb1b0_0          37 KB
#     pandas-1.2.2               |   py38hb2f4e1b_0         8.3 MB
#     path-15.1.2                |   py38hecd8cb5_0          37 KB
#     pathlib2-2.3.5             |   py38hecd8cb5_2          38 KB
#     pathspec-0.7.0             |             py_0          26 KB
#     pexpect-4.8.0              |     pyhd3eb1b0_3          53 KB
#     pickleshare-0.7.5          |  pyhd3eb1b0_1003          13 KB
#     pillow-8.1.0               |   py38h5270095_0         590 KB
#     pip-21.0.1                 |   py38hecd8cb5_0         1.8 MB
#     pkginfo-1.7.0              |   py38hecd8cb5_0          43 KB
#     prometheus_client-0.9.0    |     pyhd3eb1b0_0          45 KB
#     psutil-5.8.0               |   py38h9ed2024_1         334 KB
#     ptyprocess-0.7.0           |     pyhd3eb1b0_2          17 KB
#     py-1.10.0                  |     pyhd3eb1b0_0          76 KB
#     pycodestyle-2.6.0          |     pyhd3eb1b0_0          38 KB
#     pyerfa-1.7.2               |   py38h9ed2024_0         299 KB
#     pyflakes-2.2.0             |     pyhd3eb1b0_0          56 KB
#     pygments-2.8.0             |     pyhd3eb1b0_0         703 KB
#     pylint-2.7.0               |   py38hecd8cb5_1         449 KB
#     pyls-black-0.4.6           |       hd3eb1b0_0           9 KB
#     pyls-spyder-0.3.2          |     pyhd3eb1b0_0          10 KB
#     pyopenssl-20.0.1           |     pyhd3eb1b0_1          49 KB
#     pyparsing-2.4.7            |     pyhd3eb1b0_0          59 KB
#     pytest-6.2.2               |   py38hecd8cb5_2         442 KB
#     python-dateutil-2.8.1      |     pyhd3eb1b0_0         221 KB
#     python-language-server-0.36.2|     pyhd3eb1b0_0          41 KB
#     python-libarchive-c-2.9    |     pyhd3eb1b0_0          46 KB
#     pytz-2021.1                |     pyhd3eb1b0_0         181 KB
#     pyyaml-5.4.1               |   py38h9ed2024_1         165 KB
#     pyzmq-20.0.0               |   py38h23ab428_1         405 KB
#     qtconsole-5.0.2            |     pyhd3eb1b0_0          97 KB
#     readline-8.1               |       h9ed2024_0         333 KB
#     regex-2020.11.13           |   py38h9ed2024_0         310 KB
#     scipy-1.6.1                |   py38h2515648_0        14.5 MB
#     seaborn-0.11.1             |     pyhd3eb1b0_0         212 KB
#     send2trash-1.5.0           |     pyhd3eb1b0_1          14 KB
#     setuptools-52.0.0          |   py38hecd8cb5_0         714 KB
#     singledispatch-3.6.0       |  pyhd3eb1b0_1001          13 KB
#     snappy-1.1.8               |       hb1e8313_0          54 KB
#     snowballstemmer-2.1.0      |     pyhd3eb1b0_0          62 KB
#     sortedcollections-2.1.0    |     pyhd3eb1b0_0          12 KB
#     sortedcontainers-2.3.0     |     pyhd3eb1b0_0          26 KB
#     soupsieve-2.2              |     pyhd3eb1b0_0          32 KB
#     sphinx-3.5.1               |     pyhd3eb1b0_0         1.1 MB
#     sphinxcontrib-applehelp-1.0.2|     pyhd3eb1b0_0          29 KB
#     sphinxcontrib-devhelp-1.0.2|     pyhd3eb1b0_0          23 KB
#     sphinxcontrib-htmlhelp-1.0.3|     pyhd3eb1b0_0          28 KB
#     sphinxcontrib-jsmath-1.0.1 |     pyhd3eb1b0_0           8 KB
#     sphinxcontrib-qthelp-1.0.3 |     pyhd3eb1b0_0          26 KB
#     sphinxcontrib-serializinghtml-1.1.4|     pyhd3eb1b0_0          24 KB
#     spyder-4.2.1               |   py38hecd8cb5_1         5.7 MB
#     spyder-kernels-1.10.2      |   py38hecd8cb5_0         102 KB
#     sqlalchemy-1.3.23          |   py38h9ed2024_0         1.5 MB
#     statsmodels-0.12.2         |   py38h9ed2024_0         8.3 MB
#     sympy-1.7.1                |   py38hecd8cb5_0         8.8 MB
#     tbb-2020.3                 |       h879752b_0         147 KB
#     terminado-0.9.2            |   py38hecd8cb5_0          25 KB
#     testpath-0.4.4             |     pyhd3eb1b0_0          85 KB
#     textdistance-4.2.1         |     pyhd3eb1b0_0          29 KB
#     three-merge-0.1.1          |     pyhd3eb1b0_0          10 KB
#     toolz-0.11.1               |     pyhd3eb1b0_0          46 KB
#     tornado-6.1                |   py38h9ed2024_0         585 KB
#     tqdm-4.56.0                |     pyhd3eb1b0_0          80 KB
#     traitlets-5.0.5            |     pyhd3eb1b0_0          81 KB
#     typed-ast-1.4.2            |   py38h9ed2024_1         183 KB
#     typing_extensions-3.7.4.3  |     pyha847dfd_0          25 KB
#     ujson-4.0.2                |   py38h23ab428_0          46 KB
#     watchdog-1.0.2             |   py38h9ed2024_1          94 KB
#     werkzeug-1.0.1             |     pyhd3eb1b0_0         239 KB
#     wheel-0.36.2               |     pyhd3eb1b0_0          33 KB
#     wrapt-1.12.1               |   py38haf1e3a3_1          46 KB
#     xlrd-2.0.1                 |     pyhd3eb1b0_0          90 KB
#     xlsxwriter-1.3.7           |     pyhd3eb1b0_0         105 KB
#     xlwings-0.22.0             |   py38hecd8cb5_0         505 KB
#     zict-2.0.0                 |     pyhd3eb1b0_0          10 KB
#     zope.interface-5.2.0       |   py38h9ed2024_0         281 KB
#     ------------------------------------------------------------
#                                            Total:       113.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/osx-64::_anaconda_depends-2020.07-py38_0
#   appdirs            pkgs/main/noarch::appdirs-1.4.4-py_0
#   black              pkgs/main/noarch::black-19.10b0-py_0
#   jupyterlab_widgets pkgs/main/noarch::jupyterlab_widgets-1.0.0-pyhd3eb1b0_1
#   libllvm9           pkgs/main/osx-64::libllvm9-9.0.1-h21ff451_1
#   mypy_extensions    pkgs/main/osx-64::mypy_extensions-0.4.3-py38_0
#   pathspec           pkgs/main/noarch::pathspec-0.7.0-py_0
#   pip                pkgs/main/osx-64::pip-21.0.1-py38hecd8cb5_0
#   pyerfa             pkgs/main/osx-64::pyerfa-1.7.2-py38h9ed2024_0
#   pyls-black         pkgs/main/noarch::pyls-black-0.4.6-hd3eb1b0_0
#   pyls-spyder        pkgs/main/noarch::pyls-spyder-0.3.2-pyhd3eb1b0_0
#   snappy             pkgs/main/osx-64::snappy-1.1.8-hb1e8313_0
#   tbb                pkgs/main/osx-64::tbb-2020.3-h879752b_0
#   textdistance       pkgs/main/noarch::textdistance-4.2.1-pyhd3eb1b0_0
#   three-merge        pkgs/main/noarch::three-merge-0.1.1-pyhd3eb1b0_0
#   typed-ast          pkgs/main/osx-64::typed-ast-1.4.2-py38h9ed2024_1
#
# The following packages will be UPDATED:
#
#   anaconda-project                               0.8.4-py_0 --> 0.9.1-pyhd3eb1b0_1
#   appnope                                   0.1.0-py38_1001 --> 0.1.2-py38hecd8cb5_1001
#   appscript                            1.1.1-py38haf1e3a3_0 --> 1.1.2-py38h9ed2024_0
#   astroid                                      2.4.2-py38_0 --> 2.5-py38hecd8cb5_1
#   astropy                              4.0.2-py38haf1e3a3_0 --> 4.2-py38h9ed2024_0
#   autopep8                                       1.5.4-py_0 --> 1.5.5-pyhd3eb1b0_0
#   babel                                  2.8.1-pyhd3eb1b0_0 --> 2.9.0-pyhd3eb1b0_0
#   backports.shutil_~ pkgs/main/osx-64::backports.shutil_ge~ --> pkgs/main/noarch::backports.shutil_get_terminal_size-1.0.0-pyhd3eb1b0_3
#   bitarray                             1.6.1-py38h9ed2024_0 --> 1.6.3-py38h9ed2024_1
#   bleach                                         3.2.1-py_0 --> 3.3.0-pyhd3eb1b0_0
#   blosc                                   1.20.1-hab81aa3_0 --> 1.21.0-h2842e9f_0
#   brotlipy                          0.7.0-py38haf1e3a3_1000 --> 0.7.0-py38h9ed2024_1003
#   ca-certificates    anaconda::ca-certificates-2020.10.14-0 --> pkgs/main::ca-certificates-2021.1.19-hecd8cb5_0
#   certifi            pkgs/main/noarch::certifi-2020.6.20-p~ --> pkgs/main/osx-64::certifi-2020.12.5-py38hecd8cb5_0
#   cffi                                1.14.3-py38hed5b41f_0 --> 1.14.5-py38h2125817_0
#   cryptography                         3.1.1-py38hddc9c9b_0 --> 3.3.1-py38hbcfaee0_1
#   cython                             0.29.21-py38hb1e8313_0 --> 0.29.22-py38h23ab428_0
#   dask                                          2.30.0-py_0 --> 2021.2.0-pyhd3eb1b0_0
#   dask-core                                     2.30.0-py_0 --> 2021.2.0-pyhd3eb1b0_0
#   distributed                         2.30.1-py38hecd8cb5_0 --> 2021.2.0-py38hecd8cb5_0
#   filelock                                      3.0.12-py_0 --> 3.0.12-pyhd3eb1b0_1
#   gevent                              20.9.0-py38haf1e3a3_0 --> 21.1.1-py38h9ed2024_1
#   glib                                    2.66.1-h9bbe63b_0 --> 2.67.4-hdf23fa2_1
#   gmp                                      6.1.2-hb37e062_1 --> 6.2.1-h23ab428_2
#   greenlet                            0.4.17-py38haf1e3a3_0 --> 1.0.0-py38h23ab428_2
#   ipython                             7.19.0-py38h01d92e1_0 --> 7.20.0-py38h01d92e1_1
#   ipython_genutils   pkgs/main/osx-64::ipython_genutils-0.~ --> pkgs/main/noarch::ipython_genutils-0.2.0-pyhd3eb1b0_1
#   ipywidgets                                     7.5.1-py_1 --> 7.6.3-pyhd3eb1b0_1
#   isort                                          5.6.4-py_0 --> 5.7.0-pyhd3eb1b0_0
#   jedi                                        0.17.1-py38_0 --> 0.17.2-py38hecd8cb5_1
#   jinja2                                        2.11.2-py_0 --> 2.11.3-pyhd3eb1b0_0
#   joblib                                        0.17.0-py_0 --> 1.0.1-pyhd3eb1b0_0
#   jupyter_core                                 4.6.3-py38_0 --> 4.7.1-py38hecd8cb5_0
#   keyring                                     21.4.0-py38_1 --> 22.0.1-py38hecd8cb5_0
#   kiwisolver                           1.3.0-py38h23ab428_0 --> 1.3.1-py38h23ab428_0
#   lazy-object-proxy                    1.4.3-py38h1de35cc_0 --> 1.5.2-py38h9ed2024_0
#   locket                                       0.2.0-py38_1 --> 0.2.1-py38hecd8cb5_1
#   lxml                                 4.6.1-py38h63b7cb6_0 --> 4.6.2-py38h26b266a_0
#   lz4-c                                    1.9.2-h79c402e_3 --> 1.9.3-h23ab428_0
#   matplotlib                                        3.3.2-0 --> 3.3.4-py38hecd8cb5_0
#   matplotlib-base                      3.3.2-py38h181983e_0 --> 3.3.4-py38h8b3ea08_0
#   mkl_fft                              1.2.0-py38hc64f4ea_0 --> 1.2.1-py38ha059aab_0
#   mock                                           4.0.2-py_0 --> 4.0.3-pyhd3eb1b0_0
#   more-itertools                         8.6.0-pyhd3eb1b0_0 --> 8.7.0-pyhd3eb1b0_0
#   msgpack-python                       1.0.0-py38h04f5b5a_1 --> 1.0.2-py38hf7b0b51_1
#   nbformat                                       5.0.8-py_0 --> 5.1.2-pyhd3eb1b0_1
#   nose               pkgs/main/osx-64::nose-1.3.7-py38_1004 --> pkgs/main/noarch::nose-1.3.7-pyhd3eb1b0_1006
#   notebook                                     6.1.4-py38_0 --> 6.2.0-py38hecd8cb5_0
#   numexpr                              2.7.1-py38hce01a72_0 --> 2.7.2-py38h16bde0e_0
#   openpyxl                                       3.0.5-py_0 --> 3.0.6-pyhd3eb1b0_0
#   openssl               anaconda::openssl-1.1.1h-haf1e3a3_0 --> pkgs/main::openssl-1.1.1j-h9ed2024_0
#   packaging                                       20.4-py_0 --> 20.9-pyhd3eb1b0_0
#   pandas                               1.1.3-py38hb1e8313_0 --> 1.2.2-py38hb2f4e1b_0
#   path                                        15.0.0-py38_0 --> 15.1.2-py38hecd8cb5_0
#   pathlib2                                     2.3.5-py38_1 --> 2.3.5-py38hecd8cb5_2
#   pexpect            pkgs/main/osx-64::pexpect-4.8.0-py38_1 --> pkgs/main/noarch::pexpect-4.8.0-pyhd3eb1b0_3
#   pickleshare        pkgs/main/osx-64::pickleshare-0.7.5-p~ --> pkgs/main/noarch::pickleshare-0.7.5-pyhd3eb1b0_1003
#   pillow                               8.0.1-py38h5270095_0 --> 8.1.0-py38h5270095_0
#   pkginfo                              1.6.1-py38hecd8cb5_0 --> 1.7.0-py38hecd8cb5_0
#   prometheus_client                              0.8.0-py_0 --> 0.9.0-pyhd3eb1b0_0
#   psutil                               5.7.2-py38haf1e3a3_0 --> 5.8.0-py38h9ed2024_1
#   ptyprocess         pkgs/main/osx-64::ptyprocess-0.6.0-py~ --> pkgs/main/noarch::ptyprocess-0.7.0-pyhd3eb1b0_2
#   py                                             1.9.0-py_0 --> 1.10.0-pyhd3eb1b0_0
#   pygments                               2.7.2-pyhd3eb1b0_0 --> 2.8.0-pyhd3eb1b0_0
#   pylint                                       2.6.0-py38_0 --> 2.7.0-py38hecd8cb5_1
#   pyopenssl                                     19.1.0-py_1 --> 20.0.1-pyhd3eb1b0_1
#   pytest                                       6.1.1-py38_0 --> 6.2.2-py38hecd8cb5_2
#   python-language-s~                            0.35.1-py_0 --> 0.36.2-pyhd3eb1b0_0
#   pytz                                          2020.1-py_0 --> 2021.1-pyhd3eb1b0_0
#   pyyaml                               5.3.1-py38haf1e3a3_1 --> 5.4.1-py38h9ed2024_1
#   pyzmq                               19.0.2-py38hb1e8313_1 --> 20.0.0-py38h23ab428_1
#   qtconsole                                      4.7.7-py_0 --> 5.0.2-pyhd3eb1b0_0
#   readline                                   8.0-h1de35cc_0 --> 8.1-h9ed2024_0
#   regex                           2020.10.15-py38haf1e3a3_0 --> 2020.11.13-py38h9ed2024_0
#   scipy                                1.5.2-py38h2515648_0 --> 1.6.1-py38h2515648_0
#   seaborn                                       0.11.0-py_0 --> 0.11.1-pyhd3eb1b0_0
#   send2trash         pkgs/main/osx-64::send2trash-1.5.0-py~ --> pkgs/main/noarch::send2trash-1.5.0-pyhd3eb1b0_1
#   setuptools                          50.3.1-py38hecd8cb5_1 --> 52.0.0-py38hecd8cb5_0
#   singledispatch                            3.4.0.3-py_1001 --> 3.6.0-pyhd3eb1b0_1001
#   snowballstemmer                                2.0.0-py_0 --> 2.1.0-pyhd3eb1b0_0
#   sortedcollections                              1.2.1-py_0 --> 2.1.0-pyhd3eb1b0_0
#   sortedcontainers                               2.2.2-py_0 --> 2.3.0-pyhd3eb1b0_0
#   soupsieve                                      2.0.1-py_0 --> 2.2-pyhd3eb1b0_0
#   sphinx                                         3.2.1-py_0 --> 3.5.1-pyhd3eb1b0_0
#   spyder                                       4.1.5-py38_0 --> 4.2.1-py38hecd8cb5_1
#   spyder-kernels                               1.9.4-py38_0 --> 1.10.2-py38hecd8cb5_0
#   sqlalchemy                          1.3.20-py38h9ed2024_0 --> 1.3.23-py38h9ed2024_0
#   statsmodels                         0.12.0-py38haf1e3a3_0 --> 0.12.2-py38h9ed2024_0
#   sympy                                1.6.2-py38hecd8cb5_1 --> 1.7.1-py38hecd8cb5_0
#   terminado                                    0.9.1-py38_0 --> 0.9.2-py38hecd8cb5_0
#   tornado                              6.0.4-py38h1de35cc_1 --> 6.1-py38h9ed2024_0
#   tqdm                                          4.50.2-py_0 --> 4.56.0-pyhd3eb1b0_0
#   ujson                                4.0.1-py38hb1e8313_0 --> 4.0.2-py38h23ab428_0
#   watchdog                            0.10.3-py38haf1e3a3_0 --> 1.0.2-py38h9ed2024_1
#   wheel                                         0.35.1-py_0 --> 0.36.2-pyhd3eb1b0_0
#   wrapt                               1.11.2-py38h1de35cc_0 --> 1.12.1-py38haf1e3a3_1
#   xlrd                                           1.2.0-py_0 --> 2.0.1-pyhd3eb1b0_0
#   xlwings                                     0.20.8-py38_0 --> 0.22.0-py38hecd8cb5_0
#   zope.interface                       5.1.2-py38haf1e3a3_0 --> 5.2.0-py38h9ed2024_0
#
# The following packages will be DOWNGRADED:
#
#   alabaster                                     0.7.12-py_0 --> 0.7.12-pyhd3eb1b0_0
#   anaconda                                   2020.11-py38_0 --> custom-py38_1
#   argon2-cffi                         20.1.0-py38haf1e3a3_1 --> 20.1.0-py38h9ed2024_1
#   backcall                                       0.2.0-py_0 --> 0.2.0-pyhd3eb1b0_0
#   backports                                        1.0-py_2 --> 1.0-pyhd3eb1b0_2
#   backports.functoo~                             1.6.1-py_0 --> 1.6.1-pyhd3eb1b0_0
#   backports.tempfile                               1.0-py_1 --> 1.0-pyhd3eb1b0_1
#   beautifulsoup4                         4.9.3-pyhb0f4dca_0 --> 4.9.3-pyha847dfd_0
#   chardet                                   3.0.4-py38_1003 --> 3.0.4-py38hecd8cb5_1003
#   click                                          7.1.2-py_0 --> 7.1.2-pyhd3eb1b0_0
#   colorama                                       0.4.4-py_0 --> 0.4.4-pyhd3eb1b0_0
#   decorator                                      4.4.2-py_0 --> 4.4.2-pyhd3eb1b0_0
#   defusedxml                                     0.6.0-py_0 --> 0.6.0-pyhd3eb1b0_0
#   flask                                          1.1.2-py_0 --> 1.1.2-pyhd3eb1b0_0
#   glob2                                            0.7-py_0 --> 0.7-pyhd3eb1b0_0
#   idna                                            2.10-py_0 --> 2.10-pyhd3eb1b0_0
#   imagesize                                      1.2.0-py_0 --> 1.2.0-pyhd3eb1b0_0
#   iniconfig                                      1.1.1-py_0 --> 1.1.1-pyhd3eb1b0_0
#   itsdangerous                                   1.1.0-py_0 --> 1.1.0-pyhd3eb1b0_0
#   mkl-service                          2.3.0-py38hfbe908c_0 --> 2.3.0-py38h9ed2024_0
#   pycodestyle                                    2.6.0-py_0 --> 2.6.0-pyhd3eb1b0_0
#   pyflakes                                       2.2.0-py_0 --> 2.2.0-pyhd3eb1b0_0
#   pyparsing                                      2.4.7-py_0 --> 2.4.7-pyhd3eb1b0_0
#   python-dateutil                                2.8.1-py_0 --> 2.8.1-pyhd3eb1b0_0
#   python-libarchive~                               2.9-py_0 --> 2.9-pyhd3eb1b0_0
#   sphinxcontrib-app~                             1.0.2-py_0 --> 1.0.2-pyhd3eb1b0_0
#   sphinxcontrib-dev~                             1.0.2-py_0 --> 1.0.2-pyhd3eb1b0_0
#   sphinxcontrib-htm~                             1.0.3-py_0 --> 1.0.3-pyhd3eb1b0_0
#   sphinxcontrib-jsm~                             1.0.1-py_0 --> 1.0.1-pyhd3eb1b0_0
#   sphinxcontrib-qth~                             1.0.3-py_0 --> 1.0.3-pyhd3eb1b0_0
#   sphinxcontrib-ser~                             1.1.4-py_0 --> 1.1.4-pyhd3eb1b0_0
#   testpath                                       0.4.4-py_0 --> 0.4.4-pyhd3eb1b0_0
#   toolz                                         0.11.1-py_0 --> 0.11.1-pyhd3eb1b0_0
#   traitlets                                      5.0.5-py_0 --> 5.0.5-pyhd3eb1b0_0
#   typing_extensions                            3.7.4.3-py_0 --> 3.7.4.3-pyha847dfd_0
#   werkzeug                                       1.0.1-py_0 --> 1.0.1-pyhd3eb1b0_0
#   xlsxwriter                                     1.3.7-py_0 --> 1.3.7-pyhd3eb1b0_0
#   zict                                           2.0.0-py_0 --> 2.0.0-pyhd3eb1b0_0
#
#
# Proceed ([y]/n)?
